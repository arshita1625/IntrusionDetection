# %% [markdown]
# # Enhanced Distillation: Simplified and Tuned Student Model
# This notebook applies the following improvements:
# 1. Teacher-student distillation using only final reconstructions
# 2. Reduced distillation weight γ to 0.1
# 3. Increased student capacity to [48,24]
# 4. EarlyStopping and ReduceLROnPlateau callbacks
# 5. Threshold re-tuning via F1-score

# %%
# Step 1: Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, precision_recall_curve
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Step 2: Load and split data
df = pd.read_csv("UNSW-NB15P-MM-SAMPLE.csv")
Dn = df[df['Class'] == 0].drop(columns=['Class'])
Da = df[df['Class'] == 1].drop(columns=['Class'])
Dntr, Dnts = train_test_split(Dn, test_size=0.2, random_state=42)
Dts = pd.concat([Dnts, Da], ignore_index=True)
y_test = np.array([0]*len(Dnts) + [1]*len(Da))

# %%
# Step 3: Normalize
scaler = StandardScaler()
X_train = scaler.fit_transform(Dntr)
X_test = scaler.transform(Dts)

# %%
# Step 4: Train Teacher Model
input_dim = X_train.shape[1]
inp = Input(shape=(input_dim,))
x = Dense(64, activation='relu')(inp)
x = Dropout(0.2)(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.2)(x)
encoded = Dense(16, activation='relu')(x)
x = Dense(32, activation='relu')(encoded)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)
teacher_out = Dense(input_dim, activation='linear')(x)
teacher = Model(inp, teacher_out)
teacher.compile(optimizer=Adam(0.001), loss='mse')
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
teacher.fit(X_train, X_train, epochs=30, batch_size=256, validation_split=0.1, callbacks=[es, rlr], verbose=1)
# Out:
# Epoch 1/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step - loss: 0.6125 - val_loss: 0.2442 - learning_rate: 0.0010
# Epoch 2/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 841us/step - loss: 0.3098 - val_loss: 0.2134 - learning_rate: 0.0010
# Epoch 3/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 839us/step - loss: 0.2599 - val_loss: 0.1686 - learning_rate: 0.0010
# Epoch 4/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - loss: 0.2381 - val_loss: 0.1552 - learning_rate: 0.0010
# Epoch 5/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - loss: 0.2258 - val_loss: 0.1517 - learning_rate: 0.0010
# Epoch 6/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step - loss: 0.2176 - val_loss: 0.1443 - learning_rate: 0.0010
# Epoch 7/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 814us/step - loss: 0.2124 - val_loss: 0.1438 - learning_rate: 0.0010
# Epoch 8/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 837us/step - loss: 0.2092 - val_loss: 0.1409 - learning_rate: 0.0010
# Epoch 9/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 1000us/step - loss: 0.2113 - val_loss: 0.1399 - learning_rate: 0.0010
# Epoch 10/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 887us/step - loss: 0.1982 - val_loss: 0.1392 - learning_rate: 0.0010
# Epoch 11/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 827us/step - loss: 0.1959 - val_loss: 0.1365 - learning_rate: 0.0010
# Epoch 12/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - loss: 0.1971 - val_loss: 0.1362 - learning_rate: 0.0010
# Epoch 13/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - loss: 0.1979 - val_loss: 0.1446 - learning_rate: 0.0010
# Epoch 14/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 827us/step - loss: 0.1997 - val_loss: 0.1322 - learning_rate: 0.0010
# Epoch 15/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 867us/step - loss: 0.1873 - val_loss: 0.1606 - learning_rate: 0.0010
# Epoch 16/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - loss: 0.1926 - val_loss: 0.1320 - learning_rate: 0.0010
# Epoch 17/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 833us/step - loss: 0.1816 - val_loss: 0.1331 - learning_rate: 0.0010
# Epoch 18/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 814us/step - loss: 0.1810 - val_loss: 0.1293 - learning_rate: 0.0010
# Epoch 19/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - loss: 0.1810 - val_loss: 0.1367 - learning_rate: 0.0010
# Epoch 20/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step - loss: 0.1806 - val_loss: 0.1280 - learning_rate: 0.0010
# Epoch 21/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step - loss: 0.1794 - val_loss: 0.1296 - learning_rate: 0.0010
# Epoch 22/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 837us/step - loss: 0.1747 - val_loss: 0.1280 - learning_rate: 0.0010
# Epoch 23/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 813us/step - loss: 0.1743 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 24/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 855us/step - loss: 0.1746 - val_loss: 0.1245 - learning_rate: 5.0000e-04
# Epoch 25/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 832us/step - loss: 0.1725 - val_loss: 0.1225 - learning_rate: 5.0000e-04
# Epoch 26/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 829us/step - loss: 0.1667 - val_loss: 0.1235 - learning_rate: 5.0000e-04
# Epoch 27/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - loss: 0.1683 - val_loss: 0.1237 - learning_rate: 5.0000e-04
# Epoch 28/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 813us/step - loss: 0.1698 - val_loss: 0.1196 - learning_rate: 5.0000e-04
# Epoch 29/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 882us/step - loss: 0.1653 - val_loss: 0.1186 - learning_rate: 5.0000e-04
# Epoch 30/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 828us/step - loss: 0.1641 - val_loss: 0.1256 - learning_rate: 5.0000e-04

# %%
# Step 5: Generate Teacher Reconstructions
T_train = teacher.predict(X_train)
T_test = teacher.predict(X_test)
# Out:
# 8570/8570 ━━━━━━━━━━━━━━━━━━━━ 2s 197us/step
# 2837/2837 ━━━━━━━━━━━━━━━━━━━━ 1s 200us/step

# %%
# Step 6: Build Larger Student Model
def build_student():
    inp_s = Input(shape=(input_dim,))
    x = Dense(48, activation='relu')(inp_s)
    x = Dense(24, activation='relu')(x)
    x = Dense(48, activation='relu')(x)
    out_s = Dense(input_dim, activation='linear')(x)
    return Model(inp_s, out_s)
student = build_student()

# %%
# Step 7: Distillation with Simplified Targets
gamma = 0.1  # lower distillation weight
distill = Model(student.input, [student.output, student.output])
distill.compile(
    optimizer=Adam(5e-4),
    loss=['mse', 'mse'],
    loss_weights=[1.0, gamma]
)
es2 = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
rlr2 = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
distill.fit(
    X_train, [X_train, T_train],
    epochs=30, batch_size=256, validation_split=0.1,
    callbacks=[es2, rlr2], verbose=1
)
# Out:
# Epoch 1/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 696us/step - dense_19_loss: 0.3757 - loss: 0.5638 - val_dense_19_loss: 0.0954 - val_loss: 0.1258 - learning_rate: 5.0000e-04
# Epoch 2/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step
30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 605us/step - dense_19_loss: 0.0976 - loss: 0.0150 - val_dense_19_loss: 0.0987 - val_loss: 0.0151 - learning_rate: 5.0000e-04
# Epoch 21/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - dense_19_loss: 0.0958 - loss: 0.0145 - val_dense_19_loss: 0.1008 - val_loss: 0.0185 - learning_rate: 5.0000e-04
# Epoch 22/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 641us/step - dense_19_loss: 0.0983 - loss: 0.0152 - val_dense_19_loss: 0.0982 - val_loss: 0.0139 - learning_rate: 2.5000e-04
# Epoch 23/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 719us/step - dense_19_loss: 0.0983 - loss: 0.0142 - val_dense_19_loss: 0.0982 - val_loss: 0.0140 - learning_rate: 2.5000e-04
# Epoch 24/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - dense_19_loss: 0.0969 - loss: 0.0139 - val_dense_19_loss: 0.0985 - val_loss: 0.0138 - learning_rate: 2.5000e-04
# Epoch 25/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step - dense_19_loss: 0.0977 - loss: 0.0139 - val_dense_19_loss: 0.0994 - val_loss: 0.0141 - learning_rate: 2.5000e-04
# Epoch 26/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 607us/step - dense_19_loss: 0.0974 - loss: 0.0136 - val_dense_19_loss: 0.0983 - val_loss: 0.0136 - learning_rate: 1.2500e-04
# Epoch 27/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 634us/step - dense_19_loss: 0.0985 - loss: 0.0138 - val_dense_19_loss: 0.0987 - val_loss: 0.0136 - learning_rate: 1.2500e-04
# Epoch 28/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 626us/step - dense_19_loss: 0.0973 - loss: 0.0136 - val_dense_19_loss: 0.0984 - val_loss: 0.0134 - learning_rate: 1.2500e-04
# Epoch 29/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 598us/step - dense_19_loss: 0.0991 - loss: 0.0138 - val_dense_19_loss: 0.0984 - val_loss: 0.0136 - learning_rate: 1.2500e-04
# Epoch 30/30
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 659us/step - dense_19_loss: 0.0962 - loss: 0.0133 - val_dense_19_loss: 0.0986 - val_loss: 0.0136 - learning_rate: 1.2500e-04

# %%
# Step 8: Evaluate Student Model
S_pred = student.predict(X_test)
errors_s = np.mean((X_test - S_pred)**2, axis=1)
prec, rec, thr = precision_recall_curve(y_test, errors_s)
f1_scores = 2*(prec*rec)/(prec+rec+1e-8)
best_thr = thr[np.argmax(f1_scores)]
y_pred = (errors_s > best_thr).astype(int)
cm = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:', cm)
print(classification_report(y_test, y_pred, target_names=['Normal','Attack']))
tn, fp, fn, tp = cm.ravel()
print(f"FPR: {fp/(fp+tn):.4f}, FNR: {fn/(fn+tp):.4f}")
print(f"ROC-AUC: {roc_auc_score(y_test, errors_s):.4f}")
# Out:
# 2837/2837 ━━━━━━━━━━━━━━━━━━━━ 1s 204us/step
# Confusion Matrix: [[65424  3133]
#  [  301 21914]]
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.97     68557
#       Attack       0.87      0.99      0.93     22215
#
#     accuracy                           0.96     90772
#    macro avg       0.94      0.97      0.95     90772
# weighted avg       0.97      0.96      0.96     90772
#
# FPR: 0.0457, FNR: 0.0135
# ROC-AUC: 0.9923
