# %% [markdown]
# # Enhanced Distillation: Simplified and Tuned Student Model
# This notebook applies the following improvements:
# 1. Teacher-student distillation using only final reconstructions
# 2. Reduced distillation weight γ to 0.1
# 3. Increased student capacity to [48,24]
# 4. EarlyStopping and ReduceLROnPlateau callbacks
# 5. Threshold re-tuning via F1-score

# %%
# Step 1: Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, precision_recall_curve
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Step 2: Load and split data
df = pd.read_csv("UNSW-NB15P-MM-SAMPLE.csv")
Dn = df[df['Class'] == 0].drop(columns=['Class'])
Da = df[df['Class'] == 1].drop(columns=['Class'])
Dntr, Dnts = train_test_split(Dn, test_size=0.2, random_state=42)
Dts = pd.concat([Dnts, Da], ignore_index=True)
y_test = np.array([0]*len(Dnts) + [1]*len(Da))

# %%
# Step 3: Normalize
scaler = StandardScaler()
X_train = scaler.fit_transform(Dntr)
X_test = scaler.transform(Dts)

# %%
# Step 4: Train Teacher Model
input_dim = X_train.shape[1]
inp = Input(shape=(input_dim,))
x = Dense(64, activation='relu')(inp)
x = Dropout(0.2)(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.2)(x)
encoded = Dense(16, activation='relu')(x)
x = Dense(32, activation='relu')(encoded)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)
teacher_out = Dense(input_dim, activation='linear')(x)
teacher = Model(inp, teacher_out)
teacher.compile(optimizer=Adam(0.001), loss='mse')
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
teacher.fit(X_train, X_train, epochs=50, batch_size=256, validation_split=0.1, callbacks=[es, rlr], verbose=1)
# Out:
# Epoch 1/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6446 - val_loss: 0.2782 - learning_rate: 0.0010
# Epoch 2/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 839us/step - loss: 0.3296 - val_loss: 0.1917 - learning_rate: 0.0010
# Epoch 3/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - loss: 0.2839 - val_loss: 0.1687 - learning_rate: 0.0010
# Epoch 4/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 860us/step - loss: 0.2451 - val_loss: 0.1627 - learning_rate: 0.0010
# Epoch 5/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 820us/step - loss: 0.2308 - val_loss: 0.1581 - learning_rate: 0.0010
# Epoch 6/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 927us/step - loss: 0.2320 - val_loss: 0.1437 - learning_rate: 0.0010
# Epoch 7/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 904us/step - loss: 0.2192 - val_loss: 0.1400 - learning_rate: 0.0010
# Epoch 8/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 880us/step - loss: 0.2101 - val_loss: 0.1414 - learning_rate: 0.0010
# Epoch 9/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - loss: 0.2021 - val_loss: 0.1508 - learning_rate: 0.0010
# Epoch 10/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 933us/step - loss: 0.1991 - val_loss: 0.1344 - learning_rate: 0.0010
# Epoch 11/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 910us/step - loss: 0.2038 - val_loss: 0.1379 - learning_rate: 0.0010
# Epoch 12/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1941 - val_loss: 0.1327 - learning_rate: 0.0010
# Epoch 13/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2020 - val_loss: 0.1348 - learning_rate: 0.0010
# Epoch 14/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1894 - val_loss: 0.1355 - learning_rate: 0.0010
# Epoch 15/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 945us/step - loss: 0.1976 - val_loss: 0.1319 - learning_rate: 0.0010
# Epoch 16/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 858us/step - loss: 0.1941 - val_loss: 0.1274 - learning_rate: 0.0010
# Epoch 17/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 753us/step - loss: 0.1849 - val_loss: 0.1265 - learning_rate: 0.0010
# Epoch 18/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 0.1834 - val_loss: 0.1341 - learning_rate: 0.0010
# Epoch 19/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - loss: 0.1875 - val_loss: 0.1278 - learning_rate: 0.0010
# Epoch 20/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 0.1845 - val_loss: 0.1266 - learning_rate: 0.0010
# Epoch 21/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - loss: 0.1781 - val_loss: 0.1210 - learning_rate: 5.0000e-04
# Epoch 22/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 698us/step - loss: 0.1722 - val_loss: 0.1242 - learning_rate: 5.0000e-04
# Epoch 23/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - loss: 0.1741 - val_loss: 0.1230 - learning_rate: 5.0000e-04
# Epoch 24/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - loss: 0.1770 - val_loss: 0.1231 - learning_rate: 5.0000e-04
# Epoch 25/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 734us/step - loss: 0.1683 - val_loss: 0.1219 - learning_rate: 2.5000e-04
# Epoch 26/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 0.1686 - val_loss: 0.1224 - learning_rate: 2.5000e-04

# %%
# Step 5: Generate Teacher Reconstructions
T_train = teacher.predict(X_train)
T_test = teacher.predict(X_test)
# Out:
# 8570/8570 ━━━━━━━━━━━━━━━━━━━━ 1s 166us/step
# 2837/2837 ━━━━━━━━━━━━━━━━━━━━ 1s 180us/step

# %%
# Step 6: Build Larger Student Model
def build_student():
    inp_s = Input(shape=(input_dim,))
    x = Dense(48, activation='relu')(inp_s)
    x = Dense(24, activation='relu')(x)
    x = Dense(48, activation='relu')(x)
    out_s = Dense(input_dim, activation='linear')(x)
    return Model(inp_s, out_s)
student = build_student()

# %%
# Step 7: Distillation with Simplified Targets
gamma = 0.1  # lower distillation weight
distill = Model(student.input, [student.output, student.output])
distill.compile(
    optimizer=Adam(5e-4),
    loss=['mse', 'mse'],
    loss_weights=[1.0, gamma]
)
es2 = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
rlr2 = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
distill.fit(
    X_train, [X_train, T_train],
    epochs=50, batch_size=256, validation_split=0.1,
    callbacks=[es2, rlr2], verbose=1
)
# Out:
# Epoch 1/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 602us/step - dense_9_loss: 0.3780 - loss: 0.5740 - val_dense_9_loss: 0.0911 - val_loss: 0.1421 - learning_rate: 5.0000e-04
# Epoch 2/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - dense_9_loss: 0.0873 - loss: 0.1213 - val_dense_9_loss: 0.0798 - val_loss: 0.0761 - learning_rate: 5.0000e-04
# Epoch 3/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - dense_9_loss: 0.0817 - loss: 0.0700 - val_dense_9_loss: 0.0809 - val_loss: 0.0550 - learning_rate: 5.0000e-04
# Epoch 4/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - dense_9_loss: 0.0829 - loss: 0.0507 - val_dense_9_loss: 0.0843 - val_loss: 0.0427 - learning_rate: 5.0000e-04
# Epoch 5/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - dense_9_loss: 0.0864 - loss: 0.0404 - val_dense_9_loss: 0.0881 - val_loss: 0.0346 - learning_rate: 5.0000e-04
# Epoch 6/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 505us/step - dense_9_loss: 0.0895 - loss: 0.0329 - val_dense_9_loss: 0.0904 - val_loss: 0.0287 - learning_rate: 5.0000e-04
# Epoch 7/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - dense_9_loss: 0.0914 - loss: 0.0281 - val_dense_9_loss: 0.0935 - val_loss: 0.0253 - learning_rate: 5.0000e-04
# Epoch 8/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 529us/step - dense_9_loss: 0.0955 - loss: 0.0259 - val_dense_9_loss: 0.0950 - val_loss: 0.0231 - learning_rate: 5.0000e-04
# Epoch 9/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 531us/step - dense_9_loss: 0.0957 - loss: 0.0236 - val_dense_9_loss: 0.0963 - val_loss: 0.0215 - learning_rate: 5.0000e-04
# Epoch 10/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - dense_9_loss: 0.0963 - loss: 0.0220 - val_dense_9_loss: 0.0973 - val_loss: 0.0204 - learning_rate: 5.0000e-04
# Epoch 11/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - dense_9_loss: 0.0954 - loss: 0.0206 - val_dense_9_loss: 0.0991 - val_loss: 0.0217 - learning_rate: 5.0000e-04
# Epoch 12/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - dense_9_loss: 0.0964 - loss: 0.0199 - val_dense_9_loss: 0.0977 - val_loss: 0.0189 - learning_rate: 5.0000e-04
# Epoch 13/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - dense_9_loss: 0.0964 - loss: 0.0198 - val_dense_9_loss: 0.0980 - val_loss: 0.0185 - learning_rate: 5.0000e-04
# Epoch 14/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 544us/step - dense_9_loss: 0.0984 - loss: 0.0150 - val_dense_9_loss: 0.0996 - val_loss: 0.0152 - learning_rate: 6.2500e-05
# Epoch 38/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 509us/step - dense_9_loss: 0.0987 - loss: 0.0151 - val_dense_9_loss: 0.0998 - val_loss: 0.0152 - learning_rate: 6.2500e-05
# Epoch 39/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 519us/step - dense_9_loss: 0.0979 - loss: 0.0147 - val_dense_9_loss: 0.0999 - val_loss: 0.0153 - learning_rate: 6.2500e-05
# Epoch 40/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 513us/step - dense_9_loss: 0.0987 - loss: 0.0148 - val_dense_9_loss: 0.0997 - val_loss: 0.0151 - learning_rate: 6.2500e-05
# Epoch 41/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 508us/step - dense_9_loss: 0.1001 - loss: 0.0150 - val_dense_9_loss: 0.0997 - val_loss: 0.0151 - learning_rate: 6.2500e-05
# Epoch 42/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 547us/step - dense_9_loss: 0.0981 - loss: 0.0147 - val_dense_9_loss: 0.0998 - val_loss: 0.0150 - learning_rate: 6.2500e-05
# Epoch 43/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 507us/step - dense_9_loss: 0.0975 - loss: 0.0146 - val_dense_9_loss: 0.0998 - val_loss: 0.0151 - learning_rate: 6.2500e-05
# Epoch 44/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 507us/step - dense_9_loss: 0.0979 - loss: 0.0146 - val_dense_9_loss: 0.0997 - val_loss: 0.0150 - learning_rate: 3.1250e-05
# Epoch 45/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - dense_9_loss: 0.0987 - loss: 0.0147 - val_dense_9_loss: 0.0998 - val_loss: 0.0150 - learning_rate: 3.1250e-05
# Epoch 46/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 515us/step - dense_9_loss: 0.0983 - loss: 0.0146 - val_dense_9_loss: 0.0998 - val_loss: 0.0150 - learning_rate: 3.1250e-05
# Epoch 47/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 521us/step - dense_9_loss: 0.0988 - loss: 0.0146 - val_dense_9_loss: 0.0998 - val_loss: 0.0149 - learning_rate: 1.5625e-05
# Epoch 48/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 550us/step - dense_9_loss: 0.0992 - loss: 0.0147 - val_dense_9_loss: 0.0998 - val_loss: 0.0149 - learning_rate: 1.5625e-05
# Epoch 49/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 521us/step - dense_9_loss: 0.0987 - loss: 0.0147 - val_dense_9_loss: 0.0997 - val_loss: 0.0149 - learning_rate: 1.5625e-05
# Epoch 50/50
# 965/965 ━━━━━━━━━━━━━━━━━━━━ 1s 508us/step - dense_9_loss: 0.0998 - loss: 0.0149 - val_dense_9_loss: 0.0998 - val_loss: 0.0149 - learning_rate: 1.5625e-05

# %%
# Step 8: Evaluate Student Model
S_pred = student.predict(X_test)
errors_s = np.mean((X_test - S_pred)**2, axis=1)
prec, rec, thr = precision_recall_curve(y_test, errors_s)
f1_scores = 2*(prec*rec)/(prec+rec+1e-8)
best_thr = thr[np.argmax(f1_scores)]
y_pred = (errors_s > best_thr).astype(int)
cm = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:', cm)
print(classification_report(y_test, y_pred, target_names=['Normal','Attack']))
tn, fp, fn, tp = cm.ravel()
print(f"FPR: {fp/(fp+tn):.4f}, FNR: {fn/(fn+tp):.4f}")
print(f"ROC-AUC: {roc_auc_score(y_test, errors_s):.4f}")
# Out:
# 2837/2837 ━━━━━━━━━━━━━━━━━━━━ 0s 167us/step
# Confusion Matrix: [[64606  3951]
#  [  445 21770]]
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.94      0.97     68557
#       Attack       0.85      0.98      0.91     22215
#
#     accuracy                           0.95     90772
#    macro avg       0.92      0.96      0.94     90772
# weighted avg       0.96      0.95      0.95     90772
#
# FPR: 0.0576, FNR: 0.0200
# ROC-AUC: 0.9868
